# %% [markdown]
# <a href="https://colab.research.google.com/github/DavideLodesani/MLPNS2021/blob/main/Midterm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import preprocessing
import pylab as pl
import numpy as np
from sklearn.cluster  import KMeans
import scipy.optimize


pl.rcParams['font.size'] = 18

# %%
datain = pd.read_csv("https://raw.githubusercontent.com/fedhere/MLPNS2021/main/"
                     "midterm/country_pop.csv")

# %%
datain = datain.set_index('Data Source')

# %%
print("there are {} countries and {} time stamps in the data".
      format(*datain.shape))
# Out:
# there are 264 countries and 61 time stamps in the data

# %%
datain = datain.dropna(axis= 1,how='all')

# %%
datain = datain.dropna()

# %%
datain.shape
# Out:
# (258, 60)

# %%
datain.head()
# Out:
#                 1960.0     1961.0  ...      2018.0      2019.0
# Data Source                        ...
# Aruba          54211.0    55438.0  ...    105845.0    106314.0
# Afghanistan  8996973.0  9169410.0  ...  37172386.0  38041754.0
# Angola       5454933.0  5531472.0  ...  30809762.0  31825295.0
# Albania      1608800.0  1659800.0  ...   2866376.0   2854191.0
# Andorra        13411.0    14375.0  ...     77006.0     77142.0
#
# [5 rows x 60 columns]

# %%
print("there are {} countries and {} time stamps in the cleaned data".
      format(*datain.shape))
# Out:
# there are 258 countries and 60 time stamps in the cleaned data

# %%
datain["1960.0"].unique()
# Out:
# array([5.42110000e+04, 8.99697300e+06, 5.45493300e+06, 1.60880000e+06,
#        1.34110000e+04, 9.21977530e+07, 9.24180000e+04, 2.04817790e+07,
#        1.87412100e+06, 2.01230000e+04, 5.41310000e+04, 1.02764770e+07,
#        7.04753900e+06, 3.89539700e+06, 2.79793200e+06, 9.15348900e+06,
#        2.43162200e+06, 4.82928800e+06, 4.80135040e+07, 7.86737400e+06,
#        1.62427000e+05, 1.09534000e+05, 3.22566800e+06, 8.19800000e+06,
#        9.20640000e+04, 4.44000000e+04, 3.65695500e+06, 7.21792260e+07,
#        2.30980000e+05, 8.17020000e+04, 2.23288000e+05, 5.02745000e+05,
#        1.50166800e+06, 1.79090090e+07, 9.14017640e+07, 5.32782700e+06,
#        1.09420000e+05, 8.13299000e+06, 6.67070000e+08, 3.50355300e+06,
#        5.17691800e+06, 1.52482510e+07, 1.01825300e+06, 1.60577140e+07,
#        1.91121000e+05, 2.01765000e+05, 1.33078200e+06, 4.19471300e+06,
#        7.14125000e+06, 1.24826000e+05, 7.86500000e+03, 5.72930000e+05,
# ...

# %%
years = range(1960,2020)

# %%
ax = pl.figure(figsize=(10,10)).add_subplot(111)
for f in range(0,258):
    pl.scatter(years,datain.iloc[f])
